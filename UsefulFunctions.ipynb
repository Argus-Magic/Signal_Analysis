# %%
import MatrixFunctions as mf
import numpy as np
import matplotlib.pyplot as plt

a = [2, 4, 5]
b = [1500, 2000, 4000]

P = mf.TaylorInterpolation(a, b)

x = np.linspace(2, 6, 100)
y = np.floor(P(x))

plt.plot(x, y)
plt.plot(a,b, 'ro')
plt.show()
